# %%
#import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load the dataset
survey_result = pd.read_csv('desktop/survey_results_public.csv')

# %%
survey_result.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
#checking the shape 
survey_result.shape
# Out:
# (64461, 61)

# %%
#describing the dataset
survey_result.describe(include= 'all')
# Out:
#           Respondent                      MainBranch Hobbyist           Age  \
# count   64461.000000                           64162    64416  45446.000000
# unique           NaN                               5        2           NaN
# top              NaN  I am a developer by profession      Yes           NaN
# freq             NaN                           47193    50388           NaN
# mean    32554.079738                             NaN      NaN     30.834111
# std     18967.442360                             NaN      NaN      9.585392
# min         1.000000                             NaN      NaN      1.000000
# 25%     16116.000000                             NaN      NaN     24.000000
# 50%     32231.000000                             NaN      NaN     29.000000
# 75%     49142.000000                             NaN      NaN     35.000000
# max     65639.000000                             NaN      NaN    279.000000
#
# ...

# %%
#correlation
corr = survey_result.corr()
corr
# Out:
#                Respondent       Age  CompTotal  ConvertedComp  WorkWeekHrs
# Respondent       1.000000 -0.026741   0.000000      -0.005805    -0.003330
# Age             -0.026741  1.000000   0.044234       0.107002     0.050245
# CompTotal        0.000000  0.044234        NaN       0.000000    -0.000000
# ConvertedComp   -0.005805  0.107002   0.000000       1.000000     0.032612
# WorkWeekHrs     -0.003330  0.050245  -0.000000       0.032612     1.000000

# %%
#select columns that will be needed for the analysis
ds = survey_result[['MainBranch','Hobbyist','Age','Age1stCode','CompFreq','CompTotal','Country','DatabaseWorkedWith','DevType','EdLevel','Employment','JobFactors','JobSat','JobSeek','DevType','LanguageWorkedWith','WorkWeekHrs','YearsCode', 'YearsCodePro','NEWLearn']]

# %%
ds.head()
# Out:
#                                           MainBranch Hobbyist   Age  \
# 0                     I am a developer by profession      Yes   NaN
# 1                     I am a developer by profession       No   NaN
# 2                        I code primarily as a hobby      Yes   NaN
# 3                     I am a developer by profession      Yes  25.0
# 4  I used to be a developer by profession, but no...      Yes  31.0
#
#   Age1stCode CompFreq  CompTotal             Country  \
# 0         13  Monthly        NaN             Germany
# 1         19      NaN        NaN      United Kingdom
# 2         15      NaN        NaN  Russian Federation
# 3         18      NaN        NaN             Albania
# 4         16      NaN        NaN       United States
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# ...

# %%
#checking for missing values
ds.isnull().sum()
# Out:
# MainBranch              299
# Hobbyist                 45
# Age                   19015
# Age1stCode             6561
# CompFreq              24392
# CompTotal             29635
# Country                 389
# DatabaseWorkedWith    14924
# DevType               15091
# EdLevel                7030
# Employment              607
# JobFactors            15112
# JobSat                19267
# JobSeek               12734
# DevType               15091
# LanguageWorkedWith     7083
# WorkWeekHrs           23310
# YearsCode              6777
# YearsCodePro          18112
# NEWLearn               8305
# dtype: int64

# %%
#drop rows with missing values
new_ds = ds.dropna()

# %%
new_ds.isnull().sum()
# Out:
# MainBranch            0
# Hobbyist              0
# Age                   0
# Age1stCode            0
# CompFreq              0
# CompTotal             0
# Country               0
# DatabaseWorkedWith    0
# DevType               0
# EdLevel               0
# Employment            0
# JobFactors            0
# JobSat                0
# JobSeek               0
# DevType               0
# LanguageWorkedWith    0
# WorkWeekHrs           0
# YearsCode             0
# YearsCodePro          0
# NEWLearn              0
# dtype: int64

# %%
#check shape of the new dataset
new_ds.shape
# Out:
# (24778, 20)
