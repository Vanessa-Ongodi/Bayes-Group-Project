# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
survey_data = pd.read_csv('survey_results_public.csv')

# %%
survey_data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0   European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1  Pound sterling  ...                         NaN                    NaN
# 2             NaN  ...  Neither easy nor difficult  Appropriate in length
# 3    Albanian lek  ...                         NaN                    NaN
# 4             NaN  ...                        Easy              Too short
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 1   NaN  Computer science, computer engineering, or sof...
# 2   NaN                                                NaN
# 3    No  Computer science, computer engineering, or sof...
# 4    No  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4   Django;Ruby on Rails         Ruby on Rails
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 0   Just as welcome now as I felt last year        50.0        36           27
# 1  Somewhat more welcome now than last year         NaN         7            4
# 2  Somewhat more welcome now than last year         NaN         4          NaN
# 3  Somewhat less welcome now than last year        40.0         7            4
# 4   Just as welcome now as I felt last year         NaN        15            8
#
# [5 rows x 61 columns]

# %%
survey_data.shape
# Out:
# (64461, 61)

# %%
survey_data.describe(include='all')
# Out:
#           Respondent                      MainBranch Hobbyist           Age  \
# count   64461.000000                           64162    64416  45446.000000
# unique           NaN                               5        2           NaN
# top              NaN  I am a developer by profession      Yes           NaN
# freq             NaN                           47193    50388           NaN
# mean    32554.079738                             NaN      NaN     30.834111
# std     18967.442360                             NaN      NaN      9.585392
# min         1.000000                             NaN      NaN      1.000000
# 25%     16116.000000                             NaN      NaN     24.000000
# 50%     32231.000000                             NaN      NaN     29.000000
# 75%     49142.000000                             NaN      NaN     35.000000
# max     65639.000000                             NaN      NaN    279.000000
#
#        Age1stCode CompFreq      CompTotal  ConvertedComp        Country  \
# count       57900    40069   3.482600e+04   3.475600e+04          64072
# unique         63        3            NaN            NaN            183
# top            15   Yearly            NaN            NaN  United States
# freq         5618    19818            NaN            NaN          12469
# mean          NaN      NaN  3.190464e+242   1.037561e+05            NaN
# std           NaN      NaN            inf   2.268853e+05            NaN
# min           NaN      NaN   0.000000e+00   0.000000e+00            NaN
# 25%           NaN      NaN   2.000000e+04   2.464800e+04            NaN
# 50%           NaN      NaN   6.300000e+04   5.404900e+04            NaN
# 75%           NaN      NaN   1.250000e+05   9.500000e+04            NaN
# max           NaN      NaN  1.111111e+247   2.000000e+06            NaN
#
#                 CurrencyDesc  ... SurveyEase           SurveyLength  Trans  \
# count                  45472  ...      51802                  51701  49345
# unique                   142  ...          3                      3      2
# top     United States dollar  ...       Easy  Appropriate in length     No
# freq                   11050  ...      34626                  38769  48871
# mean                     NaN  ...        NaN                    NaN    NaN
# std                      NaN  ...        NaN                    NaN    NaN
# min                      NaN  ...        NaN                    NaN    NaN
# 25%                      NaN  ...        NaN                    NaN    NaN
# 50%                      NaN  ...        NaN                    NaN    NaN
# 75%                      NaN  ...        NaN                    NaN    NaN
# max                      NaN  ...        NaN                    NaN    NaN
#
#                                            UndergradMajor  \
# count                                               50995
# unique                                                 12
# top     Computer science, computer engineering, or sof...
# freq                                                31582
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        WebframeDesireNextYear WebframeWorkedWith  \
# count                   40024              42279
# unique                   3986               3789
# top                  React.js             jQuery
# freq                     2480               2079
# mean                      NaN                NaN
# std                       NaN                NaN
# min                       NaN                NaN
# 25%                       NaN                NaN
# 50%                       NaN                NaN
# 75%                       NaN                NaN
# max                       NaN                NaN
#
#                                   WelcomeChange   WorkWeekHrs YearsCode  \
# count                                     52683  41151.000000     57684
# unique                                        6           NaN        52
# top     Just as welcome now as I felt last year           NaN        10
# freq                                      37201           NaN      4510
# mean                                        NaN     40.782174       NaN
# std                                         NaN     17.816383       NaN
# min                                         NaN      1.000000       NaN
# 25%                                         NaN     40.000000       NaN
# 50%                                         NaN     40.000000       NaN
# 75%                                         NaN     44.000000       NaN
# max                                         NaN    475.000000       NaN
#
#        YearsCodePro
# count         46349
# unique           52
# top               3
# freq           4815
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN
#
# [11 rows x 61 columns]

# %%
survey_data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %% [markdown]
# #### Selecting needed columns

# %%
df = survey_data[[# Demographics
    'MainBranch', 'Country', 'Age', 'Gender', 'Employment', 'EdLevel', 
    # Experience
    'Age1stCode', 'Hobbyist', 'LanguageWorkedWith', 'YearsCode', 'YearsCodePro',
    # Job Satisfaction
    'DevType', 'CompFreq', 'CompTotal', 'JobFactors', 'ConvertedComp', 'JobSat', 'NEWLearn', 'WorkWeekHrs']
    ]

# %%
df.head()
# Out:
#                                           MainBranch             Country  \
# 0                     I am a developer by profession             Germany
# 1                     I am a developer by profession      United Kingdom
# 2                        I code primarily as a hobby  Russian Federation
# 3                     I am a developer by profession             Albania
# 4  I used to be a developer by profession, but no...       United States
#
#     Age Gender                                         Employment  \
# 0   NaN    Man  Independent contractor, freelancer, or self-em...
# 1   NaN    NaN                                 Employed full-time
# 2   NaN    NaN                                                NaN
# 3  25.0    Man                                                NaN
# 4  31.0    Man                                 Employed full-time
#
#                                            EdLevel Age1stCode Hobbyist  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         13      Yes
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)         19       No
# 2                                              NaN         15      Yes
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         18      Yes
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)         16      Yes
#
#          LanguageWorkedWith YearsCode YearsCodePro  \
# 0    C#;HTML/CSS;JavaScript        36           27
# 1          JavaScript;Swift         7            4
# 2  Objective-C;Python;Swift         4          NaN
# 3                       NaN         7            4
# 4         HTML/CSS;Ruby;SQL        15            8
#
#                                              DevType CompFreq  CompTotal  \
# 0  Developer, desktop or enterprise applications;...  Monthly        NaN
# 1            Developer, full-stack;Developer, mobile      NaN        NaN
# 2                                                NaN      NaN        NaN
# 3                                                NaN      NaN        NaN
# 4                                                NaN      NaN        NaN
#
#                                           JobFactors  ConvertedComp  \
# 0  Languages, frameworks, and other technologies ...            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3  Flex time or a flexible schedule;Office enviro...            NaN
# 4                                                NaN            NaN
#
#                   JobSat       NEWLearn  WorkWeekHrs
# 0     Slightly satisfied    Once a year         50.0
# 1      Very dissatisfied    Once a year          NaN
# 2                    NaN  Once a decade          NaN
# 3  Slightly dissatisfied    Once a year         40.0
# 4                    NaN    Once a year          NaN

# %%
df.shape
# Out:
# (64461, 19)

# %% [markdown]
# #### Visualizing missing data

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MainBranch          64162 non-null  object
#  1   Country             64072 non-null  object
#  2   Age                 45446 non-null  float64
#  3   Gender              50557 non-null  object
#  4   Employment          63854 non-null  object
#  5   EdLevel             57431 non-null  object
#  6   Age1stCode          57900 non-null  object
#  7   Hobbyist            64416 non-null  object
#  8   LanguageWorkedWith  57378 non-null  object
#  9   YearsCode           57684 non-null  object
#  10  YearsCodePro        46349 non-null  object
#  11  DevType             49370 non-null  object
#  12  CompFreq            40069 non-null  object
#  13  CompTotal           34826 non-null  float64
#  14  JobFactors          49349 non-null  object
#  15  ConvertedComp       34756 non-null  float64
#  16  JobSat              45194 non-null  object
#  17  NEWLearn            56156 non-null  object
#  18  WorkWeekHrs         41151 non-null  float64
# dtypes: float64(4), object(15)
# memory usage: 9.3+ MB

# %% [markdown]
# ## Data preprocessing and cleaning

# %% [markdown]
# #### converting object data to numeric data

# %%
df['Age1stCode'] = pd.to_numeric(df['Age1stCode'], errors='coerce')

# %%
df['YearsCode'] = pd.to_numeric(df['YearsCode'], errors='coerce')

# %%
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

# %%
df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro      CompTotal  \
# count  45446.000000  57473.000000  56784.000000  44133.000000   3.482600e+04
# mean      30.834111     15.476572     12.782051      8.869667  3.190464e+242
# std        9.585392      5.114081      9.490657      7.759961            inf
# min        1.000000      5.000000      1.000000      1.000000   0.000000e+00
# 25%       24.000000     12.000000      6.000000      3.000000   2.000000e+04
# 50%       29.000000     15.000000     10.000000      6.000000   6.300000e+04
# 75%       35.000000     18.000000     17.000000     12.000000   1.250000e+05
# max      279.000000     85.000000     50.000000     50.000000  1.111111e+247
#
#        ConvertedComp   WorkWeekHrs
# count   3.475600e+04  41151.000000
# mean    1.037561e+05     40.782174
# std     2.268853e+05     17.816383
# min     0.000000e+00      1.000000
# 25%     2.464800e+04     40.000000
# 50%     5.404900e+04     40.000000
# 75%     9.500000e+04     44.000000
# max     2.000000e+06    475.000000

# %% [markdown]
# ### Checking Age

# %%
# Age has a minimum and maximum value of 1 and 279 respectively which is an entry error
sns.boxplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# removing age less than 15 and greater than 70
df.drop(df[df.Age<15].index, inplace=True)
df.drop(df[df.Age>70].index, inplace=True)

# %% [markdown]
# #### Checking Age1stCode

# %%
sns.boxplot(df['Age1stCode'])
# Out:
# <AxesSubplot:xlabel='Age1stCode'>

# %%
# removing the outliers by dropping any value greater than 50
df.drop(df[df.Age1stCode>50].index, inplace=True)

# %% [markdown]
# #### Checking WorkWeekHrs

# %%
sns.boxplot(df['WorkWeekHrs'])
# Out:
# <AxesSubplot:xlabel='WorkWeekHrs'>

# %%
# WorkWeekHrs also have entry error with a maximum value of 475
df.drop(df[df.WorkWeekHrs>40].index, inplace=True)

# %%
df.shape
# Out:
# (52276, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52276 entries, 1 to 64460
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MainBranch          51979 non-null  object
#  1   Country             51887 non-null  object
#  2   Age                 35152 non-null  float64
#  3   Gender              39488 non-null  object
#  4   Employment          51701 non-null  object
#  5   EdLevel             45509 non-null  object
#  6   Age1stCode          45401 non-null  float64
#  7   Hobbyist            52231 non-null  object
#  8   LanguageWorkedWith  45671 non-null  object
#  9   YearsCode           44797 non-null  float64
#  10  YearsCodePro        32806 non-null  float64
#  11  DevType             37630 non-null  object
#  12  CompFreq            29420 non-null  object
#  13  CompTotal           25480 non-null  float64
#  14  JobFactors          38116 non-null  object
#  15  ConvertedComp       25427 non-null  float64
#  16  JobSat              33338 non-null  object
#  17  NEWLearn            44767 non-null  object
#  18  WorkWeekHrs         29278 non-null  float64
# dtypes: float64(7), object(12)
# memory usage: 8.0+ MB

# %% [markdown]
# #### The number of rows have reduced but there are no missing values anymore

# %%
df.shape
# Out:
# (52276, 19)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Exploring MainBranch

# %%
df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   36726
# I am a student who is learning to code                                            7854
# I am not primarily a developer, but I write code sometimes as part of my work     4063
# I code primarily as a hobby                                                       2176
# I used to be a developer by profession, but no longer am                          1160
# Name: MainBranch, dtype: int64

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(7,5))
sns.countplot(y=df['MainBranch'])
plt.title('MAINBRANCH')
# Out:
# Text(0.5, 1.0, 'MAINBRANCH')

# %% [markdown]
# #### A lot of the respondents were developers by profession closely followed by students who are learning how to code. Just a few minority used to be developers who are no longer practicing

# %% [markdown]
# ### Exploring Country

# %%
top_countries = df['Country'].value_counts().head(15)
top_countries
# Out:
# United States         9377
# India                 6426
# United Kingdom        3415
# Germany               3370
# Canada                1880
# France                1648
# Brazil                1452
# Netherlands           1212
# Poland                1118
# Australia             1015
# Spain                 1012
# Russian Federation     940
# Italy                  935
# Sweden                 797
# Pakistan               656
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=75)
plt.title('TOP 15 COUNTRIES')
sns.barplot(x=top_countries.index, y=top_countries)
# Out:
# <AxesSubplot:title={'center':'TOP 15 COUNTRIES'}, ylabel='Country'>

# %% [markdown]
# #### Majority of the respondents are from the United States and India.

# %% [markdown]
# ### Exploring Age

# %%
sns.displot(df['Age'])

# %%
# Categorizing age into groups for better visualization
ages = df['Age']
bins = [15, 30, 40, 50, 60, 70, 90]
labels = ['15-29', '30-39', '40-49', '50-59', '60-69', '70+']
agerange = pd.cut(ages, bins, labels = labels, include_lowest = True)

df['agerange'] = agerange

# %%
df['agerange'].value_counts()
# Out:
# 15-29    21049
# 30-39     9719
# 40-49     3104
# 50-59      971
# 60-69      309
# 70+          0
# Name: agerange, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.title('AGE DISTRIBUTION')
sns.countplot(df['agerange'])
# Out:
# <AxesSubplot:title={'center':'AGE DISTRIBUTION'}, xlabel='agerange', ylabel='count'>

# %% [markdown]
# #### From the graph above, it is clear that majority of the respondent were young people between the ages of 15-29. This is representative of the programming world in general.

# %% [markdown]
# ### Exploring Gender

# %%
df['Gender'].value_counts()
# Out:
# Man                                                            35696
# Woman                                                           3208
# Non-binary, genderqueer, or gender non-conforming                326
# Man;Non-binary, genderqueer, or gender non-conforming            101
# Woman;Non-binary, genderqueer, or gender non-conforming           73
# Woman;Man                                                         65
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       19
# Name: Gender, dtype: int64

# %%
# Removing responses with more than one option chosen
df.where(~(df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Man                                                  35696
# Woman                                                 3208
# Non-binary, genderqueer, or gender non-conforming      326
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(7,5))
plt.title('GENDER DISTRIBUTION OF RESPONDENTS')
sns.countplot(y=df['Gender'], palette='Set2')
# Out:
# <AxesSubplot:title={'center':'GENDER DISTRIBUTION OF RESPONDENTS'}, xlabel='count', ylabel='Gender'>

# %% [markdown]
# #### The data revealed that majority of the respondents were male which agrees with popular opinion that women and other gender are minority in programming

# %% [markdown]
# ### Exploring Employment

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      34729
# Student                                                  7547
# Independent contractor, freelancer, or self-employed     4303
# Not employed, but looking for work                       2311
# Employed part-time                                       2067
# Not employed, and not looking for work                    300
# Retired                                                   190
# Name: Employment, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.title('EMPLOYMENT DISTRIBUTION OF RESPONDENTS')
sns.countplot(y=df['Employment'], palette='viridis')
# Out:
# <AxesSubplot:title={'center':'EMPLOYMENT DISTRIBUTION OF RESPONDENTS'}, xlabel='count', ylabel='Employment'>

# %% [markdown]
# #### A lot of the respondents were employed full time, while Independent contractor, freelancer, or self-employed was third on the list.

# %% [markdown]
# ## Exploring Hobbyist

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          20543
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       10089
# Some college/university study without earning a degree                                 5934
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4231
# Associate degree (A.A., A.S., etc.)                                                    1477
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1194
# Primary/elementary school                                                               773
# Professional degree (JD, MD, etc.)                                                      606
# I never completed any formal education                                                  415
# Name: EdLevel, dtype: int64

# %%
plt.figure(figsize=(8,7))
plt.title('EDUCATION LEVEL OF RESPONDENTS')
sns.countplot(y=df['EdLevel'], palette='icefire')
# Out:
# <AxesSubplot:title={'center':'EDUCATION LEVEL OF RESPONDENTS'}, xlabel='count', ylabel='EdLevel'>

# %% [markdown]
# #### A lot of the respondents are educated at a tertiary level with a degree

# %% [markdown]
# ## Exploring Age1stCode

# %%
df['Age1stCode'].describe()
# Out:
# count    45154.000000
# mean        15.471055
# std          4.984037
# min          5.000000
# 25%         12.000000
# 50%         15.000000
# 75%         18.000000
# max         50.000000
# Name: Age1stCode, dtype: float64

# %%
# Categorizing Age1stCode into groups for better visualization
ageistcode = df['Age1stCode']
bins = [5, 20, 30, 40, 50, 60, 70]
labels = ['5-19', '20-29', '30-39', '40-49', '50-59', '60+']
age1stcode = pd.cut(ageistcode, bins, labels = labels, include_lowest = True)

df['age1stcode'] = age1stcode

# %%
df['age1stcode'].value_counts()
# Out:
# 5-19     40341
# 20-29     4239
# 30-39      473
# 40-49      101
# 50-59        0
# 60+          0
# Name: age1stcode, dtype: int64

# %%
sns.displot(df['Age1stCode'])

# %%
sns.countplot(df['age1stcode'])
# Out:
# <AxesSubplot:xlabel='age1stcode', ylabel='count'>

# %% [markdown]
# #### From the graph above, a lot of respondents started coding at a very young age which corroborated the earlier findings that many of the respondents are young people

# %% [markdown]
# ## Exploring Hobbyist

# %%
df['Hobbyist'].value_counts().to_frame()
# Out:
#      Hobbyist
# Yes     40623
# No      11350

# %%
plt.figure(figsize=(7,5))
plt.title('RESPONDENTS WHO CODED AS A HOBBY')
sns.countplot(df['Hobbyist'])
# Out:
# <AxesSubplot:title={'center':'RESPONDENTS WHO CODED AS A HOBBY'}, xlabel='Hobbyist', ylabel='count'>

# %% [markdown]
# #### The graph above showed that majority of the respondents saw coding as a hobby

# %% [markdown]
# ## Exploring LanguageWorkedWith

# %%
df['LanguageWorkedWith'].value_counts().head(15)
# Out:
# HTML/CSS;JavaScript;PHP;SQL                                    842
# HTML/CSS;JavaScript                                            745
# C#;HTML/CSS;JavaScript;SQL                                     659
# C#;HTML/CSS;JavaScript;SQL;TypeScript                          569
# Python                                                         544
# HTML/CSS;JavaScript;TypeScript                                 542
# Java                                                           453
# HTML/CSS;JavaScript;PHP                                        408
# C#                                                             342
# HTML/CSS;Java;JavaScript;SQL                                   294
# JavaScript                                                     287
# HTML/CSS;JavaScript;Python                                     270
# Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL;TypeScript    246
# HTML/CSS;Java;JavaScript                                       233
# C#;SQL                                                         230
# Name: LanguageWorkedWith, dtype: int64

# %% [markdown]
# #### Defining a function that helps split multiple answers into columns

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
lang_work = split_multicolumn(df.LanguageWorkedWith)
lang_work
# Out:
#        JavaScript  Swift  Objective-C  Python  HTML/CSS   Ruby    SQL   Java  \
# 1            True   True        False   False     False  False  False  False
# 2           False   True         True    True     False  False  False  False
# 3           False  False        False   False     False  False  False  False
# 4           False  False        False   False      True   True   True  False
# 5            True  False        False   False      True  False  False   True
# ...           ...    ...          ...     ...       ...    ...    ...    ...
# 64456       False  False        False   False     False  False  False  False
# 64457        True   True         True    True      True   True   True   True
# 64458       False  False        False   False     False  False  False  False
# 64459       False  False        False   False      True  False  False  False
# 64460        True  False        False   False      True  False   True   True
#
#           C#    PHP  ...    C++      R     Go  Haskell   Rust  Kotlin   Dart  \
# 1      False  False  ...  False  False  False    False  False   False  False
# 2      False  False  ...  False  False  False    False  False   False  False
# 3      False  False  ...  False  False  False    False  False   False  False
# 4      False  False  ...  False  False  False    False  False   False  False
# 5      False  False  ...  False  False  False    False  False   False  False
# ...      ...    ...  ...    ...    ...    ...      ...    ...     ...    ...
# 64456  False  False  ...  False  False  False    False  False   False  False
# 64457   True   True  ...   True   True   True     True   True    True   True
# 64458  False  False  ...  False  False  False    False  False   False  False
# 64459  False  False  ...  False  False  False    False  False   False  False
# 64460   True  False  ...  False  False  False    False  False   False  False
#
#         Perl  Julia  Assembly
# 1      False  False     False
# 2      False  False     False
# 3      False  False     False
# 4      False  False     False
# 5      False  False     False
# ...      ...    ...       ...
# 64456  False  False     False
# 64457   True   True      True
# 64458  False  False     False
# 64459  False  False     False
# 64460  False  False     False
#
# [52276 rows x 25 columns]

# %% [markdown]
# #### LanguageWorkedWith now have a column each

# %%
lang_work.sum().sort_values(ascending=False)
# Out:
# JavaScript               30606
# HTML/CSS                 28698
# SQL                      24379
# Python                   20085
# Java                     18509
# Bash/Shell/PowerShell    14668
# C#                       14113
# PHP                      11876
# TypeScript               11233
# C++                      11055
# C                        10120
# Go                        3872
# Kotlin                    3568
# Ruby                      3157
# Assembly                  2924
# VBA                       2633
# Swift                     2607
# R                         2562
# Rust                      2369
# Dart                      1793
# Objective-C               1753
# Scala                     1599
# Perl                      1347
# Haskell                   1032
# Julia                      399
# dtype: int64

# %% [markdown]
# #### Using word cloud to visualize LanguageWorkedWith

# %%
from wordcloud import WordCloud

# %%
words = ' '.join((lang for lang in df.LanguageWorkedWith.dropna().str.replace(';', ' ').str.replace(',', ' ')))

wc = WordCloud(collocation_threshold=int(1e6), width=800, height=400, background_color='white').generate(words)

plt.figure(figsize=(16,8))
plt.axis("off")
plt.grid(False)
plt.imshow(wc, interpolation='bilinear');

# %% [markdown]
# #### JavaScript is the most popular language worked with by the respondents

# %% [markdown]
# ## Exploring YearsCode

# %%
sns.displot(df['YearsCode'])

# %%
df['YearsCode'].describe()
# Out:
# count    44551.000000
# mean        12.290476
# std          9.267744
# min          1.000000
# 25%          5.000000
# 50%         10.000000
# 75%         16.000000
# max         50.000000
# Name: YearsCode, dtype: float64

# %%
# Categorizing YearCode into groups for better visualization
yearcode = df['YearsCode']
bins = [1, 10, 20, 30, 40, 50, 60]
labels = ['1-9', '10-19', '20-29', '30-39', '40-49', '50+']
yearscode = pd.cut(yearcode, bins, labels = labels, include_lowest = True)

df['yearscode_dist'] = yearscode

# %%
df['yearscode_dist'].value_counts()
# Out:
# 1-9      25162
# 10-19    12392
# 20-29     4416
# 30-39     2121
# 40-49      460
# 50+          0
# Name: yearscode_dist, dtype: int64

# %%
sns.countplot(df['yearscode_dist'])
# Out:
# <AxesSubplot:xlabel='yearscode_dist', ylabel='count'>

# %% [markdown]
# #### Many of the respondents just started coding and this could be because of the young nature of respondents

# %% [markdown]
# ## Exploring YearsCodePro

# %%
sns.displot(df['YearsCodePro'])

# %%
df['YearsCodePro'].describe()
# Out:
# count    32657.000000
# mean         8.657225
# std          7.519603
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         12.000000
# max         50.000000
# Name: YearsCodePro, dtype: float64

# %%
# Categorizing YearCodePro into groups for better visualization
yearcodepro = df['YearsCode']
bins = [1, 10, 20, 30, 40, 50, 60]
labels = ['1-9', '10-19', '20-29', '30-39', '40-49', '50+']
yearscodepro = pd.cut(yearcodepro, bins, labels = labels, include_lowest = True)

df['yearscodepro_dist'] = yearscodepro

# %%
df['yearscodepro_dist'].value_counts()
# Out:
# 1-9      25162
# 10-19    12392
# 20-29     4416
# 30-39     2121
# 40-49      460
# 50+          0
# Name: yearscodepro_dist, dtype: int64

# %%
sns.countplot(df['yearscodepro_dist'])
# Out:
# <AxesSubplot:xlabel='yearscodepro_dist', ylabel='count'>

# %% [markdown]
# #### Same trend appears with a lot of the respondents having between 1-9 years of experience since turning pro

# %% [markdown]
# ## Exploring DevType

# %%
df['DevType'].value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                     3531
# Developer, back-end                                                                                                                                                                                                                                                                                       2440
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                                                                                                                            1787
# Developer, back-end;Developer, full-stack                                                                                                                                                                                                                                                                 1158
# Developer, front-end                                                                                                                                                                                                                                                                                      1151
#                                                                                                                                                                                                                                                                                                           ...
# Academic researcher;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;DevOps specialist;System administrator                                                          1
# Academic researcher;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, full-stack;DevOps specialist;Educator;Engineer, data;Engineer, site reliability;Engineering manager;Scientist;System administrator       1
# Data or business analyst;Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, game or graphics;Engineer, data                                                       1
# Academic researcher;Data scientist or machine learning specialist;Developer, full-stack;Developer, mobile;Scientist                                                                                                                                                                                          1
# Data or business analyst;Developer, desktop or enterprise applications;Developer, full-stack;Developer, QA or test;Educator                                                                                                                                                                                  1
# Name: DevType, Length: 6283, dtype: int64

# %% [markdown]
# #### Splitting DevType responses into each column

# %%
devtype = split_multicolumn(df.DevType)
devtype
# Out:
#        Developer, full-stack  Developer, mobile  Designer  \
# 1                       True               True     False
# 2                      False              False     False
# 3                      False              False     False
# 4                      False              False     False
# 5                      False               True      True
# ...                      ...                ...       ...
# 64456                  False              False     False
# 64457                  False              False     False
# 64458                  False              False     False
# 64459                  False              False     False
# 64460                  False              False     False
#
#        Developer, front-end  Developer, back-end  Developer, QA or test  \
# 1                     False                False                  False
# 2                     False                False                  False
# 3                     False                False                  False
# 4                     False                False                  False
# 5                      True                False                  False
# ...                     ...                  ...                    ...
# 64456                 False                False                  False
# 64457                 False                False                  False
# 64458                 False                False                  False
# 64459                 False                False                  False
# 64460                 False                False                  False
#
#        DevOps specialist  Developer, desktop or enterprise applications  \
# 1                  False                                          False
# 2                  False                                          False
# 3                  False                                          False
# 4                  False                                          False
# 5                  False                                          False
# ...                  ...                                            ...
# 64456              False                                          False
# 64457              False                                          False
# 64458              False                                          False
# 64459              False                                          False
# 64460              False                                          False
#
#        Developer, game or graphics  Database administrator  ...  \
# 1                            False                   False  ...
# 2                            False                   False  ...
# 3                            False                   False  ...
# 4                            False                   False  ...
# 5                            False                   False  ...
# ...                            ...                     ...  ...
# 64456                        False                   False  ...
# 64457                        False                   False  ...
# 64458                        False                   False  ...
# 64459                        False                   False  ...
# 64460                        False                   False  ...
#
#        System administrator  Engineering manager  Product manager  \
# 1                     False                False            False
# 2                     False                False            False
# 3                     False                False            False
# 4                     False                False            False
# 5                     False                False            False
# ...                     ...                  ...              ...
# 64456                 False                False            False
# 64457                 False                False            False
# 64458                 False                False            False
# 64459                 False                False            False
# 64460                 False                False            False
#
#        Data or business analyst  Academic researcher  \
# 1                         False                False
# 2                         False                False
# 3                         False                False
# 4                         False                False
# 5                         False                False
# ...                         ...                  ...
# 64456                     False                False
# 64457                     False                False
# 64458                     False                False
# 64459                     False                False
# 64460                     False                False
#
#        Data scientist or machine learning specialist  Scientist  \
# 1                                              False      False
# 2                                              False      False
# 3                                              False      False
# 4                                              False      False
# 5                                              False      False
# ...                                              ...        ...
# 64456                                          False      False
# 64457                                          False      False
# 64458                                          False      False
# 64459                                          False      False
# 64460                                          False      False
#
#        Senior executive/VP  Marketing or sales professional  \
# 1                    False                            False
# 2                    False                            False
# 3                    False                            False
# 4                    False                            False
# 5                    False                            False
# ...                    ...                              ...
# 64456                 True                            False
# 64457                False                            False
# 64458                False                            False
# 64459                False                            False
# 64460                False                            False
#
#        Engineer, site reliability
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# 5                           False
# ...                           ...
# 64456                       False
# 64457                       False
# 64458                       False
# 64459                       False
# 64460                       False
#
# [52276 rows x 23 columns]

# %%
devtype.sum().sort_values(ascending=False)
# Out:
# Developer, full-stack                            20411
# Developer, back-end                              20398
# Developer, front-end                             13879
# Developer, desktop or enterprise applications     8619
# Developer, mobile                                 6962
# DevOps specialist                                 4234
# Database administrator                            4004
# Designer                                          3922
# System administrator                              3750
# Developer, embedded applications or devices       3411
# Developer, QA or test                             2886
# Data or business analyst                          2830
# Data scientist or machine learning specialist     2826
# Engineer, data                                    2675
# Academic researcher                               2589
# Developer, game or graphics                       2170
# Educator                                          2085
# Engineering manager                               1719
# Product manager                                   1616
# Scientist                                         1458
# Engineer, site reliability                        1339
# Senior executive/VP                                738
# Marketing or sales professional                    446
# dtype: int64

# %% [markdown]
# #### Calculating the percentage of Devtype

# %%
devtype_perc = devtype.mean().sort_values(ascending=False) * 100
devtype_perc
# Out:
# Developer, full-stack                            39.044686
# Developer, back-end                              39.019818
# Developer, front-end                             26.549468
# Developer, desktop or enterprise applications    16.487489
# Developer, mobile                                13.317775
# DevOps specialist                                 8.099319
# Database administrator                            7.659347
# Designer                                          7.502487
# System administrator                              7.173464
# Developer, embedded applications or devices       6.524983
# Developer, QA or test                             5.520698
# Data or business analyst                          5.413574
# Data scientist or machine learning specialist     5.405922
# Engineer, data                                    5.117071
# Academic researcher                               4.952559
# Developer, game or graphics                       4.151044
# Educator                                          3.988446
# Engineering manager                               3.288316
# Product manager                                   3.091285
# Scientist                                         2.789043
# Engineer, site reliability                        2.561405
# Senior executive/VP                               1.411738
# Marketing or sales professional                   0.853164
# dtype: float64

# %%
plt.figure(figsize=(10,7))
plt.title('JOB THAT BEST DESCRIBE YOU')
sns.barplot(x=devtype_perc, y=devtype_perc.index, palette='tab10')
# Out:
# <AxesSubplot:title={'center':'JOB THAT BEST DESCRIBE YOU'}>

# %% [markdown]
# #### Fullstack developer and backend developer are the most popular job type

# %% [markdown]
# ## Exploring CompFreq

# %%
df['CompFreq'].value_counts()
# Out:
# Yearly     14420
# Monthly    13764
# Weekly      1082
# Name: CompFreq, dtype: int64

# %%
plt.figure(figsize=(6,5))
plt.title('WEEKLY, MONTHLY, YEARLY COMPENSATION')
sns.countplot(df['CompFreq'])
# Out:
# <AxesSubplot:title={'center':'WEEKLY, MONTHLY, YEARLY COMPENSATION'}, xlabel='CompFreq', ylabel='count'>

# %% [markdown]
# ## Exploring JobFactors

# %%
df['JobFactors'].value_counts()
# Out:
# Flex time or a flexible schedule;Languages, frameworks, and other technologies I’d be working with;Remote work options                                2235
# Flex time or a flexible schedule;Languages, frameworks, and other technologies I’d be working with;Office environment or company culture              2009
# Languages, frameworks, and other technologies I’d be working with;Office environment or company culture;Opportunities for professional development    1904
# Flex time or a flexible schedule;Languages, frameworks, and other technologies I’d be working with;Opportunities for professional development         1314
# Flex time or a flexible schedule;Office environment or company culture;Opportunities for professional development                                     1284
#                                                                                                                                                       ...
# Diversity of the company or organization;Family friendliness                                                                                             2
# Diversity of the company or organization;Flex time or a flexible schedule                                                                                2
# Diversity of the company or organization;Financial performance or funding status of the company or organization                                          2
# Diversity of the company or organization;Specific department or team I’d be working on                                                                   1
# Diversity of the company or organization;How widely used or impactful my work output would be                                                            1
# Name: JobFactors, Length: 230, dtype: int64

# %%
jobfactors = split_multicolumn(df.JobFactors)
jobfactors
# Out:
#        Flex time or a flexible schedule  \
# 1                                 False
# 2                                 False
# 3                                  True
# 4                                 False
# 5                                 False
# ...                                 ...
# 64456                             False
# 64457                             False
# 64458                             False
# 64459                             False
# 64460                             False
#
#        Office environment or company culture  \
# 1                                      False
# 2                                      False
# 3                                       True
# 4                                      False
# 5                                       True
# ...                                      ...
# 64456                                  False
# 64457                                  False
# 64458                                  False
# 64459                                  False
# 64460                                  False
#
#        Opportunities for professional development  \
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
# 5                                           False
# ...                                           ...
# 64456                                       False
# 64457                                       False
# 64458                                       False
# 64459                                       False
# 64460                                       False
#
#        Diversity of the company or organization  \
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# 5                                          True
# ...                                         ...
# 64456                                     False
# 64457                                     False
# 64458                                     False
# 64459                                     False
# 64460                                     False
#
#        Languages, frameworks, and other technologies I’d be working with  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# 5                                                   True
# ...                                                  ...
# 64456                                              False
# 64457                                              False
# 64458                                              False
# 64459                                              False
# 64460                                              False
#
#        Remote work options  Family friendliness  \
# 1                    False                False
# 2                    False                False
# 3                    False                False
# 4                    False                False
# 5                    False                False
# ...                    ...                  ...
# 64456                False                False
# 64457                False                False
# 64458                False                False
# 64459                False                False
# 64460                False                False
#
#        How widely used or impactful my work output would be  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# 5                                                  False
# ...                                                  ...
# 64456                                              False
# 64457                                              False
# 64458                                              False
# 64459                                              False
# 64460                                              False
#
#        Industry that I’d be working in  \
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# 5                                False
# ...                                ...
# 64456                            False
# 64457                            False
# 64458                            False
# 64459                            False
# 64460                            False
#
#        Financial performance or funding status of the company or organization  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# 5                                                  False
# ...                                                  ...
# 64456                                              False
# 64457                                              False
# 64458                                              False
# 64459                                              False
# 64460                                              False
#
#        Specific department or team I’d be working on
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# ...                                              ...
# 64456                                          False
# 64457                                          False
# 64458                                          False
# 64459                                          False
# 64460                                          False
#
# [52276 rows x 11 columns]

# %%
jobfactors.sum().sort_values(ascending=False)
# Out:
# Languages, frameworks, and other technologies I’d be working with         19538
# Flex time or a flexible schedule                                          17044
# Office environment or company culture                                     16832
# Opportunities for professional development                                15485
# Remote work options                                                       12756
# How widely used or impactful my work output would be                       7598
# Industry that I’d be working in                                            5958
# Family friendliness                                                        4658
# Specific department or team I’d be working on                              4389
# Financial performance or funding status of the company or organization     4135
# Diversity of the company or organization                                   2623
# dtype: int64

# %%
jobfactors_perc = jobfactors.mean().sort_values(ascending=False) * 100
jobfactors_perc
# Out:
# Languages, frameworks, and other technologies I’d be working with         37.374703
# Flex time or a flexible schedule                                          32.603872
# Office environment or company culture                                     32.198332
# Opportunities for professional development                                29.621624
# Remote work options                                                       24.401255
# How widely used or impactful my work output would be                      14.534394
# Industry that I’d be working in                                           11.397199
# Family friendliness                                                        8.910399
# Specific department or team I’d be working on                              8.395822
# Financial performance or funding status of the company or organization     7.909940
# Diversity of the company or organization                                   5.017599
# dtype: float64

# %%
plt.figure(figsize=(10,7))
plt.title('JOB FACTORS THAT INFLUENCES JOB SATISFACTION')
sns.barplot(x=jobfactors_perc, y=jobfactors_perc.index, palette='tab10')
# Out:
# <AxesSubplot:title={'center':'JOB FACTORS THAT INFLUENCES JOB SATISFACTION'}>

# %% [markdown]
# #### Respondents chose Languages, frameworks, and other technologies I’d be working with as the most important job factor that influences them

# %% [markdown]
# ## Exploring JobSat

# %%
df['JobSat'].value_counts()
# Out:
# Very satisfied                        10797
# Slightly satisfied                    10317
# Slightly dissatisfied                  5170
# Neither satisfied nor dissatisfied     4249
# Very dissatisfied                      2648
# Name: JobSat, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.figure('RESPONDENTS LEVEL OF JOB SATISFACTION')
plt.xticks(rotation=75)
sns.countplot(y=df['JobSat'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='JobSat'>

# %% [markdown]
# #### From the graph above, a lot of respondents appear to be satisfied with their jobs with majority choosing very satisfied

# %% [markdown]
# ## Exploring NEWLearn

# %%
df['NEWLearn'].value_counts()
# Out:
# Every few months        16638
# Once a year             16478
# Once every few years    10444
# Once a decade             966
# Name: NEWLearn, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.figure('HOW OFTEN RESPONDENTS LEARN NEW LANGUAGE')
plt.xticks(rotation=75)
sns.countplot(y=df['NEWLearn'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='NEWLearn'>

# %% [markdown]
# ## Exploring WorkWeekHrs

# %%
df['WorkWeekHrs'].describe()
# Out:
# count    29141.000000
# mean        36.153139
# std          8.402932
# min          1.000000
# 25%         37.000000
# 50%         40.000000
# 75%         40.000000
# max         40.000000
# Name: WorkWeekHrs, dtype: float64

# %%
sns.displot(df['WorkWeekHrs'])

# %%
# Categorizing YearCodePro into groups for better visualization
workweek = df['WorkWeekHrs']
bins = [1, 10, 20, 30, 40, 50, 60]
labels = ['1-9', '10-19', '20-29', '30-39', '40-49', '50+']
workweekhours = pd.cut(workweek, bins, labels = labels, include_lowest = True)

df['workweekhours_dist'] = workweekhours

# %%
df['workweekhours_dist'].value_counts()
# Out:
# 30-39    25140
# 1-9       1758
# 20-29     1498
# 10-19      745
# 40-49        0
# 50+          0
# Name: workweekhours_dist, dtype: int64

# %%
sns.countplot(df['workweekhours_dist'])
# Out:
# <AxesSubplot:xlabel='workweekhours_dist', ylabel='count'>

# %% [markdown]
# #### Majority of the respondents have normal working hours per week

# %% [markdown]
# ## Exploring ConvertedComp

# %%
df['ConvertedComp'].describe()
# Out:
# count    2.530100e+04
# mean     1.008898e+05
# std      2.207120e+05
# min      0.000000e+00
# 25%      2.702500e+04
# 50%      5.296800e+04
# 75%      9.000000e+04
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
plt.figure(figsize = (10, 7))
sns.heatmap(df.corr(), annot = True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.columns
# Out:
# Index(['MainBranch', 'Country', 'Age', 'Gender', 'Employment', 'EdLevel',
#        'Age1stCode', 'Hobbyist', 'LanguageWorkedWith', 'YearsCode',
#        'YearsCodePro', 'DevType', 'CompFreq', 'CompTotal', 'JobFactors',
#        'ConvertedComp', 'JobSat', 'NEWLearn', 'WorkWeekHrs', 'agerange',
#        'age1stcode', 'yearscode_dist', 'yearscodepro_dist',
#        'workweekhours_dist'],
#       dtype='object')

# %% [markdown]
# ## Data Modeling

# %%
df.head()
# Out:
#                                           MainBranch             Country  \
# 1                     I am a developer by profession      United Kingdom
# 2                        I code primarily as a hobby  Russian Federation
# 3                     I am a developer by profession             Albania
# 4  I used to be a developer by profession, but no...       United States
# 5                     I am a developer by profession             Germany
#
#     Age Gender          Employment  \
# 1   NaN    NaN  Employed full-time
# 2   NaN    NaN                 NaN
# 3  25.0    Man                 NaN
# 4  31.0    Man  Employed full-time
# 5   NaN    Man  Employed full-time
#
#                                              EdLevel  Age1stCode Hobbyist  \
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        19.0       No
# 2                                                NaN        15.0      Yes
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        18.0      Yes
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        16.0      Yes
# 5  Secondary school (e.g. American high school, G...        14.0       No
#
#          LanguageWorkedWith  YearsCode  ...  \
# 1          JavaScript;Swift        7.0  ...
# 2  Objective-C;Python;Swift        4.0  ...
# 3                       NaN        7.0  ...
# 4         HTML/CSS;Ruby;SQL       15.0  ...
# 5  HTML/CSS;Java;JavaScript        6.0  ...
#
#                                           JobFactors ConvertedComp  \
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3  Flex time or a flexible schedule;Office enviro...           NaN
# 4                                                NaN           NaN
# 5  Diversity of the company or organization;Langu...           NaN
#
#                   JobSat       NEWLearn WorkWeekHrs  agerange age1stcode  \
# 1      Very dissatisfied    Once a year         NaN       NaN       5-19
# 2                    NaN  Once a decade         NaN       NaN       5-19
# 3  Slightly dissatisfied    Once a year        40.0     15-29       5-19
# 4                    NaN    Once a year         NaN     30-39       5-19
# 5     Slightly satisfied    Once a year         NaN       NaN       5-19
#
#   yearscode_dist  yearscodepro_dist workweekhours_dist
# 1            1-9                1-9                NaN
# 2            1-9                1-9                NaN
# 3            1-9                1-9              30-39
# 4          10-19              10-19                NaN
# 5            1-9                1-9                NaN
#
# [5 rows x 24 columns]

# %%
df['ConvertedComp'].isnull().sum()
# Out:
# 26975

# %%
df.dropna(subset=['ConvertedComp'], axis=0, inplace = True)

# %%
df.shape
# Out:
# (25301, 24)

# %% [markdown]
# ### Selecting the columns that will be used for modelling

# %%
df1 = df[['MainBranch', 'Age', 'Gender', 'Employment', 'EdLevel', 'Age1stCode', 'Hobbyist', 'YearsCode',
         'YearsCodePro', 'CompFreq', 'NEWLearn', 'WorkWeekHrs', 'ConvertedComp', 'JobSat']]
df1.head()
# Out:
#                                            MainBranch   Age Gender  \
# 7                      I am a developer by profession  36.0    Man
# 9                      I am a developer by profession  22.0    Man
# 10                     I am a developer by profession  23.0    Man
# 11                     I am a developer by profession  49.0    Man
# 12  I am not primarily a developer, but I write co...  53.0    Man
#
#             Employment                                            EdLevel  \
# 7   Employed full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9   Employed full-time    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10  Employed full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11  Employed full-time  Some college/university study without earning ...
# 12  Employed full-time  Secondary school (e.g. American high school, G...
#
#     Age1stCode Hobbyist  YearsCode  YearsCodePro CompFreq  \
# 7         12.0      Yes       17.0          13.0   Yearly
# 9         14.0      Yes        8.0           4.0   Yearly
# 10        13.0      Yes       10.0           2.0   Yearly
# 11        42.0       No        7.0           7.0  Monthly
# 12        14.0      Yes       35.0          20.0  Monthly
#
#                 NEWLearn  WorkWeekHrs  ConvertedComp                 JobSat
# 7            Once a year         39.0       116000.0  Slightly dissatisfied
# 9       Every few months         36.0        32315.0         Very satisfied
# 10      Every few months         40.0        40070.0  Slightly dissatisfied
# 11  Once every few years         40.0        14268.0      Very dissatisfied
# 12  Once every few years         36.0        38916.0         Very satisfied

# %%
df1.shape
# Out:
# (25301, 14)

# %% [markdown]
# ### Dropping all nan values from the dataset

# %%
df1.dropna(inplace=True)

# %%
df1.shape
# Out:
# (19568, 14)

# %%
df1.isnull().sum()
# Out:
# MainBranch       0
# Age              0
# Gender           0
# Employment       0
# EdLevel          0
# Age1stCode       0
# Hobbyist         0
# YearsCode        0
# YearsCodePro     0
# CompFreq         0
# NEWLearn         0
# WorkWeekHrs      0
# ConvertedComp    0
# JobSat           0
# dtype: int64

# %%
df1.head()
# Out:
#                                            MainBranch   Age Gender  \
# 7                      I am a developer by profession  36.0    Man
# 9                      I am a developer by profession  22.0    Man
# 10                     I am a developer by profession  23.0    Man
# 11                     I am a developer by profession  49.0    Man
# 12  I am not primarily a developer, but I write co...  53.0    Man
#
#             Employment                                            EdLevel  \
# 7   Employed full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9   Employed full-time    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10  Employed full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11  Employed full-time  Some college/university study without earning ...
# 12  Employed full-time  Secondary school (e.g. American high school, G...
#
#     Age1stCode Hobbyist  YearsCode  YearsCodePro CompFreq  \
# 7         12.0      Yes       17.0          13.0   Yearly
# 9         14.0      Yes        8.0           4.0   Yearly
# 10        13.0      Yes       10.0           2.0   Yearly
# 11        42.0       No        7.0           7.0  Monthly
# 12        14.0      Yes       35.0          20.0  Monthly
#
#                 NEWLearn  WorkWeekHrs  ConvertedComp                 JobSat
# 7            Once a year         39.0       116000.0  Slightly dissatisfied
# 9       Every few months         36.0        32315.0         Very satisfied
# 10      Every few months         40.0        40070.0  Slightly dissatisfied
# 11  Once every few years         40.0        14268.0      Very dissatisfied
# 12  Once every few years         36.0        38916.0         Very satisfied

# %% [markdown]
# ### Creating dummy variables

# %% [markdown]
# Dummy variables are created for discreet variables and columns were used to represent them. This is a technique known as `OneHotEncoding`, where columns representing a variable is given the value 1 if the value of the column corresponds with the column and 0 when it does not correspond

# %%
mainbranch = pd.get_dummies(df1['MainBranch']).rename(columns={'I am not primarily a developer, but I write code sometimes as part of my work':
                                                                               'Not primarily a developer'})

# %%
employment = pd.get_dummies(df1['Employment'])

# %%
edlevel = pd.get_dummies(df1['EdLevel'])

# %%
compfreq = pd.get_dummies(df1['CompFreq'])

# %%
newlearn = pd.get_dummies(df1['NEWLearn'])

# %%
hobbyist= pd.get_dummies(df1['Hobbyist'])

# %%
df1 = pd.concat([df1, mainbranch, employment, edlevel, hobbyist, compfreq, newlearn], axis=1)

# %%
df1.head()
# Out:
#                                            MainBranch   Age Gender  \
# 7                      I am a developer by profession  36.0    Man
# 9                      I am a developer by profession  22.0    Man
# 10                     I am a developer by profession  23.0    Man
# 11                     I am a developer by profession  49.0    Man
# 12  I am not primarily a developer, but I write co...  53.0    Man
#
#             Employment                                            EdLevel  \
# 7   Employed full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9   Employed full-time    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10  Employed full-time       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11  Employed full-time  Some college/university study without earning ...
# 12  Employed full-time  Secondary school (e.g. American high school, G...
#
#     Age1stCode Hobbyist  YearsCode  YearsCodePro CompFreq  ...  \
# 7         12.0      Yes       17.0          13.0   Yearly  ...
# 9         14.0      Yes        8.0           4.0   Yearly  ...
# 10        13.0      Yes       10.0           2.0   Yearly  ...
# 11        42.0       No        7.0           7.0  Monthly  ...
# 12        14.0      Yes       35.0          20.0  Monthly  ...
#
#    Some college/university study without earning a degree  No  Yes Monthly  \
# 7                                                   0       0    1       0
# 9                                                   0       0    1       0
# 10                                                  0       0    1       0
# 11                                                  1       1    0       1
# 12                                                  0       0    1       1
#
#     Weekly  Yearly  Every few months  Once a decade  Once a year  \
# 7        0       1                 0              0            1
# 9        0       1                 1              0            0
# 10       0       1                 1              0            0
# 11       0       0                 0              0            0
# 12       0       0                 0              0            0
#
#     Once every few years
# 7                      0
# 9                      0
# 10                     0
# 11                     1
# 12                     1
#
# [5 rows x 37 columns]

# %%
df1.drop(['MainBranch','Gender','Employment','EdLevel','Hobbyist','CompFreq','NEWLearn'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#      Age  Age1stCode  YearsCode  YearsCodePro  WorkWeekHrs  ConvertedComp  \
# 7   36.0        12.0       17.0          13.0         39.0       116000.0
# 9   22.0        14.0        8.0           4.0         36.0        32315.0
# 10  23.0        13.0       10.0           2.0         40.0        40070.0
# 11  49.0        42.0        7.0           7.0         40.0        14268.0
# 12  53.0        14.0       35.0          20.0         36.0        38916.0
#
#                    JobSat  I am a developer by profession  \
# 7   Slightly dissatisfied                               1
# 9          Very satisfied                               1
# 10  Slightly dissatisfied                               1
# 11      Very dissatisfied                               1
# 12         Very satisfied                               0
#
#     Not primarily a developer  Employed full-time  ...  \
# 7                           0                   1  ...
# 9                           0                   1  ...
# 10                          0                   1  ...
# 11                          0                   1  ...
# 12                          1                   1  ...
#
#     Some college/university study without earning a degree  No  Yes  Monthly  \
# 7                                                   0        0    1        0
# 9                                                   0        0    1        0
# 10                                                  0        0    1        0
# 11                                                  1        1    0        1
# 12                                                  0        0    1        1
#
#     Weekly  Yearly  Every few months  Once a decade  Once a year  \
# 7        0       1                 0              0            1
# 9        0       1                 1              0            0
# 10       0       1                 1              0            0
# 11       0       0                 0              0            0
# 12       0       0                 0              0            0
#
#     Once every few years
# 7                      0
# 9                      0
# 10                     0
# 11                     1
# 12                     1
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Creating independent (X) and dependent (y) variables

# %%
y = df1.pop('JobSat')
X = df1

# %% [markdown]
# ## Converting dependent variable (y) to ordinal values

# %%
def encode_label(data, reverse=False, convert=False):
    """
    This function  is used to encode the dependent variable into numeric data, in the order of magnitude.
    This is done to aid regression to be carried out on the dataset. The values ranges from 0 (Very dissatisfied) to 4 (Very satisfied)
    Two optional parameters are added for the conversion of ordinal values back to their original value.
    
    convert works with reverse, if convert is set to `True`, the values are converted back to their orginal form and for the default value 'False'
    the values are rounded to remove decimal places and to give the ordinal representation of the data.
    """
    label_dict = {
        'Very dissatisfied': 0,
        'Slightly dissatisfied': 1, 
        'Neither satisfied nor dissatisfied': 2,
        'Slightly satisfied': 3,
        'Very satisfied': 4
    }
    if reverse is not True:
        return label_dict[data]
    else:
        data = np.round(data).astype(int)
        if convert:
            decode_dict = {
            0: 'Very dissatisfied',
            1: 'Slightly dissatisfied', 
            2: 'Neither satisfied nor dissatisfied',
            3: 'Slightly satisfied',
            4: 'Very satisfied'
        }
            return decode_dict[data]
        else:
            return data

# %%
y.head()
# Out:
# 7     Slightly dissatisfied
# 9            Very satisfied
# 10    Slightly dissatisfied
# 11        Very dissatisfied
# 12           Very satisfied
# Name: JobSat, dtype: object

# %%
y = y.apply(encode_label, args=(False,))

# %%
y.head()
# Out:
# 7     1
# 9     4
# 10    1
# 11    0
# 12    4
# Name: JobSat, dtype: int64

# %% [markdown]
# ### Scaling the data to improve the accuracy of the model

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %% [markdown]
# # Testing Linear models `LinearRegression` and `Ridge` to evaluate which performs better for our model`

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge

# %%
df1.columns
# Out:
# Index(['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro', 'WorkWeekHrs',
#        'ConvertedComp', 'Not primarily a developer', 'Employed full-time',
#        'Employed part-time',
#        'Independent contractor, freelancer, or self-employed',
#        'Associate degree (A.A., A.S., etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'I never completed any formal education',
#        'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Primary/elementary school', 'Professional degree (JD, MD, etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Some college/university study without earning a degree', 'No', 'Yes',
#        'Monthly', 'Weekly', 'Yearly', 'Every few months', 'Once a decade',
#        'Once a year', 'Once every few years', 'I am a developer by profession',
#        'Not primarily a developer', 'Employed full-time', 'Employed part-time',
#        'Independent contractor, freelancer, or self-employed',
#        'Associate degree (A.A., A.S., etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'I never completed any formal education',
#        'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Primary/elementary school', 'Professional degree (JD, MD, etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Some college/university study without earning a degree', 'No', 'Yes',
#        'Monthly', 'Weekly', 'Yearly', 'Every few months', 'Once a decade',
#        'Once a year', 'Once every few years'],
#       dtype='object')

# %% [markdown]
# ### Splitting the data into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=10)

# %% [markdown]
# ### Training and fitting a linear regression model on the training set

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction and model evaluation

# %%
lm.coef_
# Out:
# array([-5.20770528e-02, -3.20186689e-02,  5.49225317e-02, -4.63373448e-04,
#         6.13347627e-02,  3.39678361e-02,  7.08089103e+12, -3.68454326e+12,
#        -1.13497825e+12, -5.14331978e+12, -3.99388033e+12,  4.66927068e+11,
#        -2.63099309e+12, -1.82514047e+12, -6.77598104e+12, -5.07490232e+12,
#        -2.49855268e+12, -1.49562533e+12,  5.95958038e+12, -1.16089346e+12,
#        -1.02929809e+13, -1.22645061e+12, -3.25490430e+12,  8.03869047e+12,
#        -2.66179425e+12,  7.29108381e+12,  8.90115939e+11, -1.11268287e+12,
#         2.22068853e+12, -4.86020250e+12, -6.57976978e+12, -4.67546582e+12,
#        -3.65095853e+12,  4.68858915e+12,  1.43056854e+12,  2.85922507e+12,
#         3.49059173e+12,  7.43407576e+12,  5.30788829e+12,  2.93400548e+12,
#         2.26589359e+12, -4.72181190e+12, -5.55547112e+12,  3.57661629e+12,
#         8.07598190e+12,  5.53265385e+12, -1.12589316e+12,  4.67674004e+11,
#        -7.96336101e+12, -3.23495266e+12, -1.03486771e+12])

# %%
pd.DataFrame(lm.coef_, df1.columns, columns = ["Coeff"])
# Out:
#                                                            Coeff
# Age                                                -5.207705e-02
# Age1stCode                                         -3.201867e-02
# YearsCode                                           5.492253e-02
# YearsCodePro                                       -4.633734e-04
# WorkWeekHrs                                         6.133476e-02
# ConvertedComp                                       3.396784e-02
# Not primarily a developer                           7.080891e+12
# Employed full-time                                 -3.684543e+12
# Employed part-time                                 -1.134978e+12
# Independent contractor, freelancer, or self-emp... -5.143320e+12
# Associate degree (A.A., A.S., etc.)                -3.993880e+12
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)        4.669271e+11
# I never completed any formal education             -2.630993e+12
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)    -1.825140e+12
# Other doctoral degree (Ph.D., Ed.D., etc.)         -6.775981e+12
# Primary/elementary school                          -5.074902e+12
# Professional degree (JD, MD, etc.)                 -2.498553e+12
# Secondary school (e.g. American high school, Ge... -1.495625e+12
# Some college/university study without earning a...  5.959580e+12
# No                                                 -1.160893e+12
# Yes                                                -1.029298e+13
# Monthly                                            -1.226451e+12
# Weekly                                             -3.254904e+12
# Yearly                                              8.038690e+12
# Every few months                                   -2.661794e+12
# Once a decade                                       7.291084e+12
# Once a year                                         8.901159e+11
# Once every few years                               -1.112683e+12
# I am a developer by profession                      2.220689e+12
# Not primarily a developer                          -4.860203e+12
# Employed full-time                                 -6.579770e+12
# Employed part-time                                 -4.675466e+12
# Independent contractor, freelancer, or self-emp... -3.650959e+12
# Associate degree (A.A., A.S., etc.)                 4.688589e+12
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)        1.430569e+12
# I never completed any formal education              2.859225e+12
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     3.490592e+12
# Other doctoral degree (Ph.D., Ed.D., etc.)          7.434076e+12
# Primary/elementary school                           5.307888e+12
# Professional degree (JD, MD, etc.)                  2.934005e+12
# Secondary school (e.g. American high school, Ge...  2.265894e+12
# Some college/university study without earning a... -4.721812e+12
# No                                                 -5.555471e+12
# Yes                                                 3.576616e+12
# Monthly                                             8.075982e+12
# Weekly                                              5.532654e+12
# Yearly                                             -1.125893e+12
# Every few months                                    4.676740e+11
# Once a decade                                      -7.963361e+12
# Once a year                                        -3.234953e+12
# Once every few years                               -1.034868e+12

# %%
lm.intercept_
# Out:
# 2.6623043002651983

# %% [markdown]
# ### Checking the $R^2$ Score, `Mean Absolute Error` (MAE) and `Root Mean Squared Error` (RMSE) of the `LinearRegression` model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
predictions = lm.predict(X_test)

# %%
predictions = pd.Series(predictions).apply(encode_label, args=(True, False))
predictions.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# dtype: int64

# %%
plt.scatter([*range(len(predictions))], predictions)

# %%
mae = mean_absolute_error(y_test, predictions)
round(mae, 3)
# Out:
# 1.042

# %%
rmse = np.sqrt(mean_squared_error(y_test, predictions))
round(rmse, 3)
# Out:
# 1.35

# %%
r2 = r2_score(y_test, predictions)
round(r2, 3)
# Out:
# -0.068

# %% [markdown]
# ### Training and fitting a Ridge regression model on the training set

# %%
rm = Ridge()

# %%
rm.fit(X_train, y_train)
# Out:
# Ridge()

# %% [markdown]
# ### Prediction and model evaluation

# %%
rm.coef_
# Out:
# array([-5.20853461e-02, -2.73851272e-02,  5.16959323e-02,  1.64825131e-03,
#         6.76522869e-02,  4.17198958e-02, -1.92258488e-03, -6.32711498e-03,
#         2.63966302e-03,  5.64069872e-03, -1.34527676e-04, -6.15652857e-03,
#        -3.85623410e-03, -1.96007583e-03,  2.42037499e-02, -1.06957277e-02,
#        -7.44084188e-03,  4.18196663e-03,  2.02175459e-03, -2.02691827e-03,
#         2.02691827e-03, -2.09241029e-02,  6.59779394e-06,  2.07304312e-02,
#        -7.97405578e-03,  1.53209313e-03,  6.66814839e-03,  3.86638955e-04,
#         1.92258487e-03, -1.92258488e-03, -6.32711498e-03,  2.63966302e-03,
#         5.64069872e-03, -1.34527676e-04, -6.15652857e-03, -3.85623410e-03,
#        -1.96007583e-03,  2.42037499e-02, -1.06957277e-02, -7.44084188e-03,
#         4.18196663e-03,  2.02175459e-03, -2.02691827e-03,  2.02691827e-03,
#        -2.09241029e-02,  6.59779392e-06,  2.07304312e-02, -7.97405578e-03,
#         1.53209313e-03,  6.66814839e-03,  3.86638955e-04])

# %%
pd.DataFrame(rm.coef_, df1.columns, columns = ["Coeff"])
# Out:
#                                                        Coeff
# Age                                                -0.052085
# Age1stCode                                         -0.027385
# YearsCode                                           0.051696
# YearsCodePro                                        0.001648
# WorkWeekHrs                                         0.067652
# ConvertedComp                                       0.041720
# Not primarily a developer                          -0.001923
# Employed full-time                                 -0.006327
# Employed part-time                                  0.002640
# Independent contractor, freelancer, or self-emp...  0.005641
# Associate degree (A.A., A.S., etc.)                -0.000135
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)       -0.006157
# I never completed any formal education             -0.003856
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)    -0.001960
# Other doctoral degree (Ph.D., Ed.D., etc.)          0.024204
# Primary/elementary school                          -0.010696
# Professional degree (JD, MD, etc.)                 -0.007441
# Secondary school (e.g. American high school, Ge...  0.004182
# Some college/university study without earning a...  0.002022
# No                                                 -0.002027
# Yes                                                 0.002027
# Monthly                                            -0.020924
# Weekly                                              0.000007
# Yearly                                              0.020730
# Every few months                                   -0.007974
# Once a decade                                       0.001532
# Once a year                                         0.006668
# Once every few years                                0.000387
# I am a developer by profession                      0.001923
# Not primarily a developer                          -0.001923
# Employed full-time                                 -0.006327
# Employed part-time                                  0.002640
# Independent contractor, freelancer, or self-emp...  0.005641
# Associate degree (A.A., A.S., etc.)                -0.000135
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)       -0.006157
# I never completed any formal education             -0.003856
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)    -0.001960
# Other doctoral degree (Ph.D., Ed.D., etc.)          0.024204
# Primary/elementary school                          -0.010696
# Professional degree (JD, MD, etc.)                 -0.007441
# Secondary school (e.g. American high school, Ge...  0.004182
# Some college/university study without earning a...  0.002022
# No                                                 -0.002027
# Yes                                                 0.002027
# Monthly                                            -0.020924
# Weekly                                              0.000007
# Yearly                                              0.020730
# Every few months                                   -0.007974
# Once a decade                                       0.001532
# Once a year                                         0.006668
# Once every few years                                0.000387

# %%
rm.intercept_
# Out:
# 2.66255774218435

# %% [markdown]
# ### Checking the $R^2$ Score, `Mean Absolute Error` (MAE) and `Root Mean Squared Error` (RMSE) of the `Ridge` model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
predictions2 = rm.predict(X_test)

# %%
predictions2 = pd.Series(predictions2).apply(encode_label, args=(True, False))
predictions2.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# dtype: int64

# %%
plt.scatter([*range(len(predictions2))], predictions2)

# %%
mae = mean_absolute_error(y_test, predictions2)
round(mae, 3)
# Out:
# 1.04

# %%
rmse = np.sqrt(mean_squared_error(y_test, predictions2))
round(rmse, 3)
# Out:
# 1.349

# %%
r2 = r2_score(y_test, predictions2)
round(r2, 3)
# Out:
# -0.067

# %%
y.to_frame().assign(value=1).groupby('JobSat').sum()
# Out:
#                                     value
# JobSat
# Neither satisfied nor dissatisfied   2193
# Slightly dissatisfied                3266
# Slightly satisfied                   6121
# Very dissatisfied                    1485
# Very satisfied                       6503

# %% [markdown]
# ## Cheking the r squared and adjusted r squared value using OLS method on the test data set

# %%
import statsmodels.api as sm

# %%
ols = sm.add_constant(X_test)
model = sm.OLS(y_test, X_test).fit()
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 JobSat   R-squared (uncentered):                   0.004
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              1.137
# Date:                Wed, 23 Feb 2022   Prob (F-statistic):                       0.294
# Time:                        16:33:44   Log-Likelihood:                         -14678.
# No. Observations:                5871   AIC:                                  2.940e+04
# Df Residuals:                    5848   BIC:                                  2.956e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0120      0.084      0.142      0.887      -0.153       0.177
# x2            -0.0318      0.048     -0.661      0.509      -0.126       0.063
# x3             0.1267      0.099      1.277      0.202      -0.068       0.321
# x4            -0.1438      0.093     -1.543      0.123      -0.327       0.039
# x5             0.0492      0.042      1.184      0.236      -0.032       0.131
# x6             0.0341      0.042      0.804      0.421      -0.049       0.117
# x7            -0.0793      0.040     -1.970      0.049      -0.158      -0.000
# x8             0.0179      0.022      0.815      0.415      -0.025       0.061
# x9             0.0243      0.035      0.700      0.484      -0.044       0.092
# x10           -0.0370      0.028     -1.327      0.185      -0.092       0.018
# x11            0.0067      0.037      0.180      0.857      -0.066       0.080
# x12           -0.0130      0.025     -0.522      0.602      -0.062       0.036
# x13            0.0176      0.037      0.475      0.635      -0.055       0.090
# x14           -0.0313      0.028     -1.105      0.269      -0.087       0.024
# x15            0.0686      0.037      1.845      0.065      -0.004       0.141
# x16           -0.0524      0.042     -1.262      0.207      -0.134       0.029
# x17           -0.0055      0.037     -0.149      0.882      -0.077       0.066
# x18           -0.0347      0.038     -0.912      0.362      -0.109       0.040
# x19            0.0519      0.032      1.608      0.108      -0.011       0.115
# x20            0.0045      0.020      0.226      0.821      -0.034       0.043
# x21           -0.0045      0.020     -0.226      0.821      -0.043       0.034
# x22           -0.0194      0.021     -0.909      0.363      -0.061       0.022
# x23           -0.0274      0.041     -0.667      0.505      -0.108       0.053
# x24            0.0282      0.022      1.308      0.191      -0.014       0.071
# x25           -0.0209      0.028     -0.755      0.450      -0.075       0.033
# x26            0.0290      0.038      0.770      0.441      -0.045       0.103
# x27           -0.0015      0.025     -0.060      0.952      -0.050       0.047
# x28            0.0139      0.028      0.493      0.622      -0.041       0.069
# ==============================================================================
# Omnibus:                      853.960   Durbin-Watson:                   0.386
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              537.824
# Skew:                          -0.619   Prob(JB):                    1.63e-117
# Kurtosis:                       2.184   Cond. No.                     1.96e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 4.77e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
