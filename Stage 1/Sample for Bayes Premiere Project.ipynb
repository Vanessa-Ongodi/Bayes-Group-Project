# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### An Insight into the Hub of Developers.
#
# * Who are they?
# * What do they do?
# * Where do they come from?

# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp

# %%
#I downloaded the dataset so I can read it directly from the folder
survey_data = pd.read_csv('survey_results_public.csv')

# %%
survey_data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
survey_data.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
survey_data.sample(10)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 45107       46045  I am not primarily a developer, but I write co...      Yes
# 29498       29608                     I am a developer by profession      Yes
# 5247         5266             I am a student who is learning to code       No
# 4214         4230                     I am a developer by profession      Yes
# 13294       13334                     I am a developer by profession      Yes
# 63667       65096                     I am a developer by profession       No
# 2325         2335                     I am a developer by profession      Yes
# 51323       52388                     I am a developer by profession      Yes
# 304           306                     I am a developer by profession      Yes
# 23998       24088                     I am a developer by profession       No
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# ...

# %%
survey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
survey_data.isna().sum()
# Out:
# Respondent                0
# MainBranch              299
# Hobbyist                 45
# Age                   19015
# Age1stCode             6561
#                       ...
# WebframeWorkedWith    22182
# WelcomeChange         11778
# WorkWeekHrs           23310
# YearsCode              6777
# YearsCodePro          18112
# Length: 61, dtype: int64

# %%
#view the schema data
schema = pd.read_csv('survey_results_schema.csv')

# %%
schema.head(60)
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
#select the  necessary columns 
update_schema = schema.iloc[[0,1,2,3,4,7,8,12,13,14,15,16,17,18,22,54,56,58,59,60]]
update_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# 7        ConvertedComp  Salary converted to annual USD salaries using ...
# 8              Country                                 Where do you live?
# 12  DatabaseWorkedWith  Which database environments have you done exte...
# 13             DevType  Which of the following describe you? Please se...
# 14             EdLevel  Which of the following best describes the high...
# 15          Employment  Which of the following best describes your cur...
# 16           Ethnicity  Which of the following describe you, if any? P...
# ...

# %%
update_schema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Column        20 non-null     object
#  1   QuestionText  20 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes

# %%
#select the same columns for the main dataset
update_survey_data = survey_data[['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'ConvertedComp', 'Country',
                                 'DatabaseWorkedWith', 'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
                                 'LanguageWorkedWith', 'UndergradMajor', 'WebframeWorkedWith', 'WorkWeekHrs', 'YearsCode', 'YearsCodePro' ]]
update_survey_data
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#remove rows with missing values from data
survey_updated = update_survey_data.dropna()
survey_updated
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 7               8  I am a developer by profession      Yes  36.0         12
# 9              10  I am a developer by profession      Yes  22.0         14
# 10             11  I am a developer by profession      Yes  23.0         13
# 13             14  I am a developer by profession      Yes  27.0         13
# 15             16  I am a developer by profession      Yes  45.0          8
# ...           ...                             ...      ...   ...        ...
# 62016       63311  I am a developer by profession      Yes  27.0         16
# 62212       63516  I am a developer by profession      Yes  30.0         21
# 63402       64810  I am a developer by profession      Yes  32.0         12
# 63517       64938  I am a developer by profession       No  33.0         13
# 63955       65414  I am a developer by profession      Yes  22.0         17
#
#        ConvertedComp         Country  \
# ...

# %%
#summarise with pandas profiling
profile = pp.ProfileReport(survey_updated) 

profile.to_file("survey.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#total countries that took the survey
country_data = survey_updated['Country'].value_counts()
country_data.to_frame()
# Out:
#                    Country
# United States         4526
# United Kingdom        1345
# Germany               1049
# India                 1031
# Canada                 734
# ...                    ...
# Yemen                    1
# Mongolia                 1
# Turkmenistan             1
# Brunei Darussalam        1
# Monaco                   1
#
# [148 rows x 1 columns]

# %%
#total age, you can use this to remove the ages that don't make sense, ages less than 14 and greater than 60 should be removed
age_data = survey_data['Age'].value_counts()
age_data.to_frame()
# Out:
#        Age
# 25.0  2693
# 28.0  2412
# 30.0  2406
# 26.0  2391
# 27.0  2338
# ...    ...
# 26.8     1
# 3.0      1
# 14.7     1
# 26.5     1
# 22.5     1
#
# [110 rows x 1 columns]

# %%
def age_label(row):
    age = row.Age
    if age <= 19:
        return "15 - 19"
    elif age <= 30:
        return "20 - 30"
    elif age <= 45:
        return "31 - 45"
    elif age <= 60:
        return "46 - 60"
    else:
        return "Above 60"

# %%
survey_data["Age_label"] = survey_data.apply(age_label, axis=1)

# %% [markdown]
# ### Demography of the Respondents

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
pie_data = survey_data.groupby("Age_label").Respondent.count()
pie_data = pie_data.to_frame()

# %%
plt.pie(x='Respondent', 
        data=pie_data, 
        radius=1.5,
        autopct='%1.2f%%',
        normalize=True, 
       )
plt.legend(labels=['14 - 19', '20 - 30', '31 - 45', '46 - 60', 'Above 60'])
plt.show()

# %%
race_count = survey_data.Ethnicity.str.split(';').explode().to_frame().reset_index().groupby('Ethnicity').count()

# %%
race_count.rename({
    'index':'Count'
}, inplace=True, axis=1)
race_count
# Out:
#                                                     Count
# Ethnicity
# Biracial                                              572
# Black or of African descent                          2062
# East Asian                                           2122
# Hispanic or Latino/a/x                               3484
# Indigenous (such as Native American, Pacific Is...    383
# Middle Eastern                                       2272
# Multiracial                                           796
# South Asian                                          4767
# Southeast Asian                                      2049
# White or of European descent                        31380

# %%
plt.figure(figsize=(10,5))
plt.bar(x=race_count.index, height=race_count['Count'], log=True) 
# using log scale to cover for large difference between maximum data and the others
plt.xticks(rotation=90)
plt.show()

# %%
survey_data[['Age1stCode', 'Age', 'YearsCode']] # Can be used to populate Age that are NaN
# Out:
#       Age1stCode   Age YearsCode
# 0             13   NaN        36
# 1             19   NaN         7
# 2             15   NaN         4
# 3             18  25.0         7
# 4             16  31.0        15
# ...          ...   ...       ...
# 64456         16   NaN        10
# 64457        NaN   NaN       NaN
# 64458        NaN   NaN       NaN
# 64459        NaN   NaN       NaN
# 64460        NaN   NaN       NaN
#
# [64461 rows x 3 columns]

# %% [markdown]
# Having issues making this lambda function work, it is supposed to fill Fields of `"Younger than 5 years"` with random numbers 3 and 4. that was the age of participants with `NaN` can be determined if there is an `Age1stCode` and `YearsCode`.

# %%
survey_data['Age1stCode'].apply(lambda x: np.random.randint(3, 5) if x == "Younger than 5 years")

# %% [markdown]
# This line is supposed to convert rows to floats and check if there are participants whose `Age1stCode` and `Years` code doesn't sum up to the years.

# %%
survey_data[survey_data['Age'] != int(survey_data['Age1stCode'].astype(float) + survey_data['YearsCode'].astype(float))]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Modelling
